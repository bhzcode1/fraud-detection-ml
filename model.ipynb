# %%
import pandas as pd
import numpy as np 
from sklearn.preprocessing import StandardScaler

# %%
data = pd.read_csv('fraudTrain.csv')

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1296675 entries, 0 to 1296674
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   Unnamed: 0             1296675 non-null  int64
#  1   trans_date_trans_time  1296675 non-null  str
#  2   cc_num                 1296675 non-null  int64
#  3   merchant               1296675 non-null  str
#  4   category               1296675 non-null  str
#  5   amt                    1296675 non-null  float64
#  6   first                  1296675 non-null  str
#  7   last                   1296675 non-null  str
#  8   gender                 1296675 non-null  str
#  9   street                 1296675 non-null  str
#  10  city                   1296675 non-null  str
#  11  state                  1296675 non-null  str
#  12  zip                    1296675 non-null  int64
#  13  lat                    1296675 non-null  float64
#  14  long                   1296675 non-null  float64
#  15  city_pop               1296675 non-null  int64
#  16  job                    1296675 non-null  str
#  17  dob                    1296675 non-null  str
#  18  trans_num              1296675 non-null  str
#  19  unix_time              1296675 non-null  int64
#  20  merch_lat              1296675 non-null  float64
#  21  merch_long             1296675 non-null  float64
#  22  is_fraud               1296675 non-null  int64
# dtypes: float64(5), int64(6), str(12)
# memory usage: 227.5 MB

# %%
data.head(2)
# Out:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0           0   2019-01-01 00:00:18  2703186189652095
# 1           1   2019-01-01 00:00:44      630423337322
#
#                           merchant     category     amt      first   last  \
# 0       fraud_Rippin, Kub and Mann     misc_net    4.97   Jennifer  Banks
# 1  fraud_Heller, Gutmann and Zieme  grocery_pos  107.23  Stephanie   Gill
#
#   gender                        street  ...      lat      long  city_pop  \
# 0      F                561 Perry Cove  ...  36.0788  -81.1781      3495
# 1      F  43039 Riley Greens Suite 393  ...  48.8878 -118.2105       149
#
#                                  job         dob  \
# 0          Psychologist, counselling  1988-03-09
# 1  Special educational needs teacher  1978-06-21
#
#                           trans_num   unix_time  merch_lat  merch_long  \
# 0  0b242abb623afc578575680df30655b9  1325376018  36.011293  -82.048315
# 1  1f76529f8574734946361c461b024d99  1325376044  49.159047 -118.186462
#
#    is_fraud
# 0         0
# 1         0
#
# [2 rows x 23 columns]

# %%
data.isnull().sum()
# Out:
# Unnamed: 0               0
# trans_date_trans_time    0
# cc_num                   0
# merchant                 0
# category                 0
# amt                      0
# first                    0
# last                     0
# gender                   0
# street                   0
# city                     0
# state                    0
# zip                      0
# lat                      0
# long                     0
# city_pop                 0
# job                      0
# dob                      0
# trans_num                0
# unix_time                0
# merch_lat                0
# merch_long               0
# is_fraud                 0
# dtype: int64

# %%
data.describe()
# Out:
#          Unnamed: 0        cc_num           amt           zip           lat  \
# count  1.296675e+06  1.296675e+06  1.296675e+06  1.296675e+06  1.296675e+06
# mean   6.483370e+05  4.171920e+17  7.035104e+01  4.880067e+04  3.853762e+01
# std    3.743180e+05  1.308806e+18  1.603160e+02  2.689322e+04  5.075808e+00
# min    0.000000e+00  6.041621e+10  1.000000e+00  1.257000e+03  2.002710e+01
# 25%    3.241685e+05  1.800429e+14  9.650000e+00  2.623700e+04  3.462050e+01
# 50%    6.483370e+05  3.521417e+15  4.752000e+01  4.817400e+04  3.935430e+01
# 75%    9.725055e+05  4.642255e+15  8.314000e+01  7.204200e+04  4.194040e+01
# max    1.296674e+06  4.992346e+18  2.894890e+04  9.978300e+04  6.669330e+01
#
#                long      city_pop     unix_time     merch_lat    merch_long  \
# count  1.296675e+06  1.296675e+06  1.296675e+06  1.296675e+06  1.296675e+06
# mean  -9.022634e+01  8.882444e+04  1.349244e+09  3.853734e+01 -9.022646e+01
# std    1.375908e+01  3.019564e+05  1.284128e+07  5.109788e+00  1.377109e+01
# min   -1.656723e+02  2.300000e+01  1.325376e+09  1.902779e+01 -1.666712e+02
# 25%   -9.679800e+01  7.430000e+02  1.338751e+09  3.473357e+01 -9.689728e+01
# 50%   -8.747690e+01  2.456000e+03  1.349250e+09  3.936568e+01 -8.743839e+01
# 75%   -8.015800e+01  2.032800e+04  1.359385e+09  4.195716e+01 -8.023680e+01
# max   -6.795030e+01  2.906700e+06  1.371817e+09  6.751027e+01 -6.695090e+01
#
#            is_fraud
# count  1.296675e+06
# mean   5.788652e-03
# std    7.586269e-02
# min    0.000000e+00
# 25%    0.000000e+00
# 50%    0.000000e+00
# 75%    0.000000e+00
# max    1.000000e+00

# %%
unscaled_data = data.copy()

# %%
unscaled_data.head(2)
# Out:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0           0   2019-01-01 00:00:18  2703186189652095
# 1           1   2019-01-01 00:00:44      630423337322
#
#                           merchant     category     amt      first   last  \
# 0       fraud_Rippin, Kub and Mann     misc_net    4.97   Jennifer  Banks
# 1  fraud_Heller, Gutmann and Zieme  grocery_pos  107.23  Stephanie   Gill
#
#   gender                        street  ...      lat      long  city_pop  \
# 0      F                561 Perry Cove  ...  36.0788  -81.1781      3495
# 1      F  43039 Riley Greens Suite 393  ...  48.8878 -118.2105       149
#
#                                  job         dob  \
# 0          Psychologist, counselling  1988-03-09
# 1  Special educational needs teacher  1978-06-21
#
#                           trans_num   unix_time  merch_lat  merch_long  \
# 0  0b242abb623afc578575680df30655b9  1325376018  36.011293  -82.048315
# 1  1f76529f8574734946361c461b024d99  1325376044  49.159047 -118.186462
#
#    is_fraud
# 0         0
# 1         0
#
# [2 rows x 23 columns]

# %%
unscaled_data['trans_date_trans_time']= pd.to_datetime(unscaled_data['trans_date_trans_time'])

unscaled_data['month'] = unscaled_data['trans_date_trans_time'].dt.month
unscaled_data['day_of_week'] = unscaled_data['trans_date_trans_time'].dt.day_of_week
unscaled_data['hours']= unscaled_data['trans_date_trans_time'].dt.hour

# %%
unscaled_data
# Out:
#          Unnamed: 0 trans_date_trans_time               cc_num  \
# 0                 0   2019-01-01 00:00:18     2703186189652095
# 1                 1   2019-01-01 00:00:44         630423337322
# 2                 2   2019-01-01 00:00:51       38859492057661
# 3                 3   2019-01-01 00:01:16     3534093764340240
# 4                 4   2019-01-01 00:03:06      375534208663984
# ...             ...                   ...                  ...
# 1296670     1296670   2020-06-21 12:12:08       30263540414123
# 1296671     1296671   2020-06-21 12:12:19     6011149206456997
# 1296672     1296672   2020-06-21 12:12:32     3514865930894695
# 1296673     1296673   2020-06-21 12:13:36     2720012583106919
# 1296674     1296674   2020-06-21 12:13:37  4292902571056973207
#
#                                     merchant       category     amt  \
# 0                 fraud_Rippin, Kub and Mann       misc_net    4.97
# 1            fraud_Heller, Gutmann and Zieme    grocery_pos  107.23
# 2                       fraud_Lind-Buckridge  entertainment  220.11
# 3         fraud_Kutch, Hermiston and Farrell  gas_transport   45.00
# 4                        fraud_Keeling-Crist       misc_pos   41.96
# ...                                      ...            ...     ...
# 1296670                    fraud_Reichel Inc  entertainment   15.56
# 1296671             fraud_Abernathy and Sons    food_dining   51.70
# 1296672                 fraud_Stiedemann Ltd    food_dining  105.93
# 1296673  fraud_Reinger, Weissnat and Strosin    food_dining   74.90
# 1296674  fraud_Langosh, Wintheiser and Hyatt    food_dining    4.30
#
#                first       last gender                         street  ...  \
# 0           Jennifer      Banks      F                 561 Perry Cove  ...
# 1          Stephanie       Gill      F   43039 Riley Greens Suite 393  ...
# 2             Edward    Sanchez      M       594 White Dale Suite 530  ...
# 3             Jeremy      White      M    9443 Cynthia Court Apt. 038  ...
# 4              Tyler     Garcia      M               408 Bradley Rest  ...
# ...              ...        ...    ...                            ...  ...
# 1296670         Erik  Patterson      M       162 Jessica Row Apt. 072  ...
# 1296671      Jeffrey      White      M  8617 Holmes Terrace Suite 651  ...
# 1296672  Christopher  Castaneda      M     1632 Cohen Drive Suite 639  ...
# 1296673       Joseph     Murray      M           42933 Ryan Underpass  ...
# 1296674      Jeffrey      Smith      M           135 Joseph Mountains  ...
#
#                                        job         dob  \
# 0                Psychologist, counselling  1988-03-09
# 1        Special educational needs teacher  1978-06-21
# 2              Nature conservation officer  1962-01-19
# 3                          Patent attorney  1967-01-12
# 4           Dance movement psychotherapist  1986-03-28
# ...                                    ...         ...
# 1296670                       Geoscientist  1961-11-24
# 1296671   Production assistant, television  1979-12-11
# 1296672                    Naval architect  1967-08-30
# 1296673              Volunteer coordinator  1980-08-18
# 1296674           Therapist, horticultural  1995-08-16
#
#                                 trans_num   unix_time  merch_lat  merch_long  \
# 0        0b242abb623afc578575680df30655b9  1325376018  36.011293  -82.048315
# 1        1f76529f8574734946361c461b024d99  1325376044  49.159047 -118.186462
# 2        a1a22d70485983eac12b5b88dad1cf95  1325376051  43.150704 -112.154481
# 3        6b849c168bdad6f867558c3793159a81  1325376076  47.034331 -112.561071
# 4        a41d7549acf90789359a9aa5346dcb46  1325376186  38.674999  -78.632459
# ...                                   ...         ...        ...         ...
# 1296670  440b587732da4dc1a6395aba5fb41669  1371816728  36.841266 -111.690765
# 1296671  278000d2e0d2277d1de2f890067dcc0a  1371816739  38.906881  -78.246528
# 1296672  483f52fe67fabef353d552c1e662974c  1371816752  33.619513 -105.130529
# 1296673  d667cdcbadaaed3da3f4020e83591c83  1371816816  42.788940 -103.241160
# 1296674  8f7c8e4ab7f25875d753b422917c98c9  1371816817  46.565983 -114.186110
#
#         is_fraud month day_of_week  hours
# 0              0     1           1      0
# 1              0     1           1      0
# 2              0     1           1      0
# 3              0     1           1      0
# 4              0     1           1      0
# ...          ...   ...         ...    ...
# 1296670        0     6           6     12
# 1296671        0     6           6     12
# 1296672        0     6           6     12
# 1296673        0     6           6     12
# 1296674        0     6           6     12
#
# [1296675 rows x 26 columns]

# %%
unscaled_data['dob']= pd.to_datetime(unscaled_data['dob'])
unscaled_data['age'] = (unscaled_data['trans_date_trans_time'] - unscaled_data['dob']).dt.days//365

# %%
unscaled_data =unscaled_data.drop(unscaled_data[['trans_date_trans_time','dob']],axis=1)

# %%
unscaled_data =unscaled_data.drop('Unnamed: 0', axis =1)

# %%
#check point 
new_unscaled_data = unscaled_data.copy()

# %%
new_unscaled_data.head()
# Out:
#              cc_num                            merchant       category  \
# 0  2703186189652095          fraud_Rippin, Kub and Mann       misc_net
# 1      630423337322     fraud_Heller, Gutmann and Zieme    grocery_pos
# 2    38859492057661                fraud_Lind-Buckridge  entertainment
# 3  3534093764340240  fraud_Kutch, Hermiston and Farrell  gas_transport
# 4   375534208663984                 fraud_Keeling-Crist       misc_pos
#
#       amt      first     last gender                        street  \
# 0    4.97   Jennifer    Banks      F                561 Perry Cove
# 1  107.23  Stephanie     Gill      F  43039 Riley Greens Suite 393
# 2  220.11     Edward  Sanchez      M      594 White Dale Suite 530
# 3   45.00     Jeremy    White      M   9443 Cynthia Court Apt. 038
# 4   41.96      Tyler   Garcia      M              408 Bradley Rest
#
#              city state  ...                                job  \
# 0  Moravian Falls    NC  ...          Psychologist, counselling
# 1          Orient    WA  ...  Special educational needs teacher
# 2      Malad City    ID  ...        Nature conservation officer
# 3         Boulder    MT  ...                    Patent attorney
# 4        Doe Hill    VA  ...     Dance movement psychotherapist
#
#                           trans_num   unix_time  merch_lat  merch_long  \
# 0  0b242abb623afc578575680df30655b9  1325376018  36.011293  -82.048315
# 1  1f76529f8574734946361c461b024d99  1325376044  49.159047 -118.186462
# 2  a1a22d70485983eac12b5b88dad1cf95  1325376051  43.150704 -112.154481
# 3  6b849c168bdad6f867558c3793159a81  1325376076  47.034331 -112.561071
# 4  a41d7549acf90789359a9aa5346dcb46  1325376186  38.674999  -78.632459
#
#   is_fraud  month  day_of_week  hours  age
# 0        0      1            1      0   30
# 1        0      1            1      0   40
# 2        0      1            1      0   56
# 3        0      1            1      0   52
# 4        0      1            1      0   32
#
# [5 rows x 24 columns]

# %%
new_unscaled_data['gender'] = new_unscaled_data['gender'].map({'M':0,'F':1})

# %%
new_unscaled_data
# Out:
#                       cc_num                             merchant  \
# 0           2703186189652095           fraud_Rippin, Kub and Mann
# 1               630423337322      fraud_Heller, Gutmann and Zieme
# 2             38859492057661                 fraud_Lind-Buckridge
# 3           3534093764340240   fraud_Kutch, Hermiston and Farrell
# 4            375534208663984                  fraud_Keeling-Crist
# ...                      ...                                  ...
# 1296670       30263540414123                    fraud_Reichel Inc
# 1296671     6011149206456997             fraud_Abernathy and Sons
# 1296672     3514865930894695                 fraud_Stiedemann Ltd
# 1296673     2720012583106919  fraud_Reinger, Weissnat and Strosin
# 1296674  4292902571056973207  fraud_Langosh, Wintheiser and Hyatt
#
#               category     amt        first       last  gender  \
# 0             misc_net    4.97     Jennifer      Banks       1
# 1          grocery_pos  107.23    Stephanie       Gill       1
# 2        entertainment  220.11       Edward    Sanchez       0
# 3        gas_transport   45.00       Jeremy      White       0
# 4             misc_pos   41.96        Tyler     Garcia       0
# ...                ...     ...          ...        ...     ...
# 1296670  entertainment   15.56         Erik  Patterson       0
# 1296671    food_dining   51.70      Jeffrey      White       0
# 1296672    food_dining  105.93  Christopher  Castaneda       0
# 1296673    food_dining   74.90       Joseph     Murray       0
# 1296674    food_dining    4.30      Jeffrey      Smith       0
#
#                                 street                      city state  ...  \
# 0                       561 Perry Cove            Moravian Falls    NC  ...
# 1         43039 Riley Greens Suite 393                    Orient    WA  ...
# 2             594 White Dale Suite 530                Malad City    ID  ...
# 3          9443 Cynthia Court Apt. 038                   Boulder    MT  ...
# 4                     408 Bradley Rest                  Doe Hill    VA  ...
# ...                                ...                       ...   ...  ...
# 1296670       162 Jessica Row Apt. 072                     Hatch    UT  ...
# 1296671  8617 Holmes Terrace Suite 651                 Tuscarora    MD  ...
# 1296672     1632 Cohen Drive Suite 639  High Rolls Mountain Park    NM  ...
# 1296673           42933 Ryan Underpass                 Manderson    SD  ...
# 1296674           135 Joseph Mountains                      Sula    MT  ...
#
#                                        job                         trans_num  \
# 0                Psychologist, counselling  0b242abb623afc578575680df30655b9
# 1        Special educational needs teacher  1f76529f8574734946361c461b024d99
# 2              Nature conservation officer  a1a22d70485983eac12b5b88dad1cf95
# 3                          Patent attorney  6b849c168bdad6f867558c3793159a81
# 4           Dance movement psychotherapist  a41d7549acf90789359a9aa5346dcb46
# ...                                    ...                               ...
# 1296670                       Geoscientist  440b587732da4dc1a6395aba5fb41669
# 1296671   Production assistant, television  278000d2e0d2277d1de2f890067dcc0a
# 1296672                    Naval architect  483f52fe67fabef353d552c1e662974c
# 1296673              Volunteer coordinator  d667cdcbadaaed3da3f4020e83591c83
# 1296674           Therapist, horticultural  8f7c8e4ab7f25875d753b422917c98c9
#
#           unix_time  merch_lat  merch_long is_fraud  month  day_of_week  \
# 0        1325376018  36.011293  -82.048315        0      1            1
# 1        1325376044  49.159047 -118.186462        0      1            1
# 2        1325376051  43.150704 -112.154481        0      1            1
# 3        1325376076  47.034331 -112.561071        0      1            1
# 4        1325376186  38.674999  -78.632459        0      1            1
# ...             ...        ...         ...      ...    ...          ...
# 1296670  1371816728  36.841266 -111.690765        0      6            6
# 1296671  1371816739  38.906881  -78.246528        0      6            6
# 1296672  1371816752  33.619513 -105.130529        0      6            6
# 1296673  1371816816  42.788940 -103.241160        0      6            6
# 1296674  1371816817  46.565983 -114.186110        0      6            6
#
#          hours  age
# 0            0   30
# 1            0   40
# 2            0   56
# 3            0   52
# 4            0   32
# ...        ...  ...
# 1296670     12   58
# 1296671     12   40
# 1296672     12   52
# 1296673     12   39
# 1296674     12   24
#
# [1296675 rows x 24 columns]

# %%
new_unscaled_data['category'].unique()
# Out:
# <StringArray>
# [      'misc_net',    'grocery_pos',  'entertainment',  'gas_transport',
#        'misc_pos',    'grocery_net',   'shopping_net',   'shopping_pos',
#     'food_dining',  'personal_care', 'health_fitness',         'travel',
#       'kids_pets',           'home']
# Length: 14, dtype: str

# %%
new_unscaled_data = pd.get_dummies(new_unscaled_data,columns=['category'],drop_first= True)

# %%
new_unscaled_data.columns.values
# Out:
# <StringArray>
# [                 'cc_num',                'merchant',
#                      'amt',                   'first',
#                     'last',                  'gender',
#                   'street',                    'city',
#                    'state',                     'zip',
#                      'lat',                    'long',
#                 'city_pop',                     'job',
#                'trans_num',               'unix_time',
#                'merch_lat',              'merch_long',
#                 'is_fraud',                   'month',
#              'day_of_week',                   'hours',
#                      'age',    'category_food_dining',
#   'category_gas_transport',    'category_grocery_net',
#     'category_grocery_pos', 'category_health_fitness',
#            'category_home',      'category_kids_pets',
#        'category_misc_net',       'category_misc_pos',
#   'category_personal_care',   'category_shopping_net',
#    'category_shopping_pos',         'category_travel']
# Length: 36, dtype: str

# %%
new_unscaled_data['merchant'].unique()
# Out:
# <StringArray>
# [         'fraud_Rippin, Kub and Mann',     'fraud_Heller, Gutmann and Zieme',
#                 'fraud_Lind-Buckridge',  'fraud_Kutch, Hermiston and Farrell',
#                  'fraud_Keeling-Crist',    'fraud_Stroman, Hudson and Erdman',
#                'fraud_Rowe-Vandervort',                'fraud_Corwin-Collins',
#                     'fraud_Herzog Ltd',   'fraud_Schoen, Kuphal and Nitzsche',
#  ...
#   'fraud_Kohler, Lindgren and Koelpin',                'fraud_Heller-Abshire',
#   'fraud_Swift, Bradtke and Marquardt',   'fraud_Larson, Quitzon and Spencer',
#  'fraud_Kilback, Nitzsche and Leffler',              'fraud_Jakubowski Group',
#                'fraud_Breitenberg LLC',                   'fraud_Collier Inc',
#                    'fraud_Paucek-Wiza',                 'fraud_Kessler Group']
# Length: 693, dtype: str

# %%
for col in ['merchant','job','city','state']:
 print(col,'->',new_unscaled_data[col].nunique())
# Out:
# merchant -> 693
# job -> 494
# city -> 894
# state -> 51

# %%
merchant_freq = new_unscaled_data['merchant'].value_counts()
new_unscaled_data['merchant_freq'] = new_unscaled_data['merchant'].map(merchant_freq)

job_freq = new_unscaled_data['job'].value_counts()
new_unscaled_data['job_freq'] = new_unscaled_data['job'].map(job_freq)

city_freq = new_unscaled_data['city'].value_counts()
new_unscaled_data['city_freq'] = new_unscaled_data['city'].map(city_freq)

state_freq = new_unscaled_data['state'].value_counts()
new_unscaled_data['state_freq'] = new_unscaled_data['state'].map(state_freq)

# %%
new_unscaled_data.drop(['merchant','job','city','state'],axis=1,inplace=True)

# %%
new_unscaled_data.head(2)
new_unscaled_data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1296675 entries, 0 to 1296674
# Data columns (total 36 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   cc_num                   1296675 non-null  int64
#  1   amt                      1296675 non-null  float64
#  2   first                    1296675 non-null  str
#  3   last                     1296675 non-null  str
#  4   gender                   1296675 non-null  int64
#  5   street                   1296675 non-null  str
#  6   zip                      1296675 non-null  int64
#  7   lat                      1296675 non-null  float64
#  8   long                     1296675 non-null  float64
#  9   city_pop                 1296675 non-null  int64
#  10  trans_num                1296675 non-null  str
#  11  unix_time                1296675 non-null  int64
#  12  merch_lat                1296675 non-null  float64
#  13  merch_long               1296675 non-null  float64
#  14  is_fraud                 1296675 non-null  int64
#  15  month                    1296675 non-null  int32
#  16  day_of_week              1296675 non-null  int32
#  17  hours                    1296675 non-null  int32
#  18  age                      1296675 non-null  int64
#  19  category_food_dining     1296675 non-null  bool
#  20  category_gas_transport   1296675 non-null  bool
#  21  category_grocery_net     1296675 non-null  bool
#  22  category_grocery_pos     1296675 non-null  bool
#  23  category_health_fitness  1296675 non-null  bool
#  24  category_home            1296675 non-null  bool
#  25  category_kids_pets       1296675 non-null  bool
#  26  category_misc_net        1296675 non-null  bool
#  27  category_misc_pos        1296675 non-null  bool
#  28  category_personal_care   1296675 non-null  bool
#  29  category_shopping_net    1296675 non-null  bool
#  30  category_shopping_pos    1296675 non-null  bool
#  31  category_travel          1296675 non-null  bool
#  32  merchant_freq            1296675 non-null  int64
#  33  job_freq                 1296675 non-null  int64
#  34  city_freq                1296675 non-null  int64
#  35  state_freq               1296675 non-null  int64
# dtypes: bool(13), float64(5), int32(3), int64(11), str(4)
# memory usage: 228.8 MB

# %%
new_unscaled_data.columns.values
# Out:
# <StringArray>
# [                 'cc_num',                     'amt',
#                    'first',                    'last',
#                   'gender',                  'street',
#                      'zip',                     'lat',
#                     'long',                'city_pop',
#                'trans_num',               'unix_time',
#                'merch_lat',              'merch_long',
#                 'is_fraud',                   'month',
#              'day_of_week',                   'hours',
#                      'age',    'category_food_dining',
#   'category_gas_transport',    'category_grocery_net',
#     'category_grocery_pos', 'category_health_fitness',
#            'category_home',      'category_kids_pets',
#        'category_misc_net',       'category_misc_pos',
#   'category_personal_care',   'category_shopping_net',
#    'category_shopping_pos',         'category_travel',
#            'merchant_freq',                'job_freq',
#                'city_freq',              'state_freq']
# Length: 36, dtype: str

# %%
new_unscaled_data.head(2)
# Out:
#              cc_num     amt      first   last  gender  \
# 0  2703186189652095    4.97   Jennifer  Banks       1
# 1      630423337322  107.23  Stephanie   Gill       1
#
#                          street    zip      lat      long  city_pop  ...  \
# 0                561 Perry Cove  28654  36.0788  -81.1781      3495  ...
# 1  43039 Riley Greens Suite 393  99160  48.8878 -118.2105       149  ...
#
#   category_misc_net  category_misc_pos  category_personal_care  \
# 0              True              False                   False
# 1             False              False                   False
#
#    category_shopping_net  category_shopping_pos  category_travel  \
# 0                  False                  False            False
# 1                  False                  False            False
#
#    merchant_freq  job_freq  city_freq  state_freq
# 0           1267      3545       2028       30266
# 1           2503      5099       3545       18924
#
# [2 rows x 36 columns]

# %%
import numpy as np

def haversine_distance(lat1, lon1, lat2, lon2):
    # Convert degrees to radians
    lat1, lon1, lat2, lon2 = map(np.radians, [lat1, lon1, lat2, lon2])
    
    dlat = lat2 - lat1
    dlon = lon2 - lon1
    
    a = np.sin(dlat/2)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon/2)**2
    c = 2 * np.arcsin(np.sqrt(a))
    
    earth_radius_km = 6371
    return earth_radius_km * c

new_unscaled_data['distance_km'] = haversine_distance(new_unscaled_data['lat'], new_unscaled_data['long'], new_unscaled_data['merch_lat'], new_unscaled_data['merch_long'])

# %%
new_unscaled_data.head(2)
# Out:
#              cc_num     amt      first   last  gender  \
# 0  2703186189652095    4.97   Jennifer  Banks       1
# 1      630423337322  107.23  Stephanie   Gill       1
#
#                          street    zip      lat      long  city_pop  ...  \
# 0                561 Perry Cove  28654  36.0788  -81.1781      3495  ...
# 1  43039 Riley Greens Suite 393  99160  48.8878 -118.2105       149  ...
#
#   category_misc_pos  category_personal_care  category_shopping_net  \
# 0             False                   False                  False
# 1             False                   False                  False
#
#    category_shopping_pos  category_travel  merchant_freq  job_freq  city_freq  \
# 0                  False            False           1267      3545       2028
# 1                  False            False           2503      5099       3545
#
#    state_freq  distance_km
# 0       30266    78.597568
# 1       18924    30.212176
#
# [2 rows x 37 columns]

# %%
#check point 2
new_unscaled_data2 = new_unscaled_data.drop(['lat', 'long', 'merch_lat', 'merch_long'], axis=1)

# %%
new_unscaled_data2['unix_time']
# Out:
# 0          1325376018
# 1          1325376044
# 2          1325376051
# 3          1325376076
# 4          1325376186
#               ...
# 1296670    1371816728
# 1296671    1371816739
# 1296672    1371816752
# 1296673    1371816816
# 1296674    1371816817
# Name: unix_time, Length: 1296675, dtype: int64

# %%
new_unscaled_data2.columns.values
# Out:
# <StringArray>
# [                 'cc_num',                     'amt',
#                    'first',                    'last',
#                   'gender',                  'street',
#                      'zip',                'city_pop',
#                'trans_num',               'unix_time',
#                 'is_fraud',                   'month',
#              'day_of_week',                   'hours',
#                      'age',    'category_food_dining',
#   'category_gas_transport',    'category_grocery_net',
#     'category_grocery_pos', 'category_health_fitness',
#            'category_home',      'category_kids_pets',
#        'category_misc_net',       'category_misc_pos',
#   'category_personal_care',   'category_shopping_net',
#    'category_shopping_pos',         'category_travel',
#            'merchant_freq',                'job_freq',
#                'city_freq',              'state_freq',
#              'distance_km']
# Length: 33, dtype: str

# %%
new_unscaled_data2 = new_unscaled_data2.drop(['trans_num', 'street', 'zip', 'unix_time'], axis=1)

# %%
new_unscaled_data2.columns.values
# Out:
# <StringArray>
# [                 'cc_num',                     'amt',
#                    'first',                    'last',
#                   'gender',                'city_pop',
#                 'is_fraud',                   'month',
#              'day_of_week',                   'hours',
#                      'age',    'category_food_dining',
#   'category_gas_transport',    'category_grocery_net',
#     'category_grocery_pos', 'category_health_fitness',
#            'category_home',      'category_kids_pets',
#        'category_misc_net',       'category_misc_pos',
#   'category_personal_care',   'category_shopping_net',
#    'category_shopping_pos',         'category_travel',
#            'merchant_freq',                'job_freq',
#                'city_freq',              'state_freq',
#              'distance_km']
# Length: 29, dtype: str

# %%
new_unscaled_data2
# Out:
#                       cc_num     amt        first       last  gender  \
# 0           2703186189652095    4.97     Jennifer      Banks       1
# 1               630423337322  107.23    Stephanie       Gill       1
# 2             38859492057661  220.11       Edward    Sanchez       0
# 3           3534093764340240   45.00       Jeremy      White       0
# 4            375534208663984   41.96        Tyler     Garcia       0
# ...                      ...     ...          ...        ...     ...
# 1296670       30263540414123   15.56         Erik  Patterson       0
# 1296671     6011149206456997   51.70      Jeffrey      White       0
# 1296672     3514865930894695  105.93  Christopher  Castaneda       0
# 1296673     2720012583106919   74.90       Joseph     Murray       0
# 1296674  4292902571056973207    4.30      Jeffrey      Smith       0
#
#          city_pop  is_fraud  month  day_of_week  hours  ...  \
# 0            3495         0      1            1      0  ...
# 1             149         0      1            1      0  ...
# 2            4154         0      1            1      0  ...
# 3            1939         0      1            1      0  ...
# 4              99         0      1            1      0  ...
# ...           ...       ...    ...          ...    ...  ...
# 1296670       258         0      6            6     12  ...
# 1296671       100         0      6            6     12  ...
# 1296672       899         0      6            6     12  ...
# 1296673      1126         0      6            6     12  ...
# 1296674       218         0      6            6     12  ...
#
#          category_misc_pos  category_personal_care  category_shopping_net  \
# 0                    False                   False                  False
# 1                    False                   False                  False
# 2                    False                   False                  False
# 3                    False                   False                  False
# 4                     True                   False                  False
# ...                    ...                     ...                    ...
# 1296670              False                   False                  False
# 1296671              False                   False                  False
# 1296672              False                   False                  False
# 1296673              False                   False                  False
# 1296674              False                   False                  False
#
#          category_shopping_pos  category_travel  merchant_freq  job_freq  \
# 0                        False            False           1267      3545
# 1                        False            False           2503      5099
# 2                        False            False           1895       511
# 3                        False            False           2613      2530
# 4                        False            False           1592      2017
# ...                        ...              ...            ...       ...
# 1296670                  False            False           1907      5620
# 1296671                  False            False           1751       531
# 1296672                  False            False           1853      8684
# 1296673                  False            False           1910      2024
# 1296674                  False            False           1788      2528
#
#          city_freq  state_freq  distance_km
# 0             2028       30266    78.597568
# 1             3545       18924    30.212176
# 2              503        5545   108.206083
# 3              493       11754    95.673231
# 4             2017       29250    77.556744
# ...            ...         ...          ...
# 1296670       1513       10699   119.752136
# 1296671        531       26193    75.104085
# 1296672       2070       16407    99.047734
# 1296673       2024       12324    84.627652
# 1296674       1512       11754    83.853655
#
# [1296675 rows x 29 columns]

# %%
new_unscaled_data2 = new_unscaled_data2.drop(['cc_num','first','last'], axis=1)

# %%
new_unscaled_data2.head(2)
# Out:
#       amt  gender  city_pop  is_fraud  month  day_of_week  hours  age  \
# 0    4.97       1      3495         0      1            1      0   30
# 1  107.23       1       149         0      1            1      0   40
#
#    category_food_dining  category_gas_transport  ...  category_misc_pos  \
# 0                 False                   False  ...              False
# 1                 False                   False  ...              False
#
#    category_personal_care  category_shopping_net  category_shopping_pos  \
# 0                   False                  False                  False
# 1                   False                  False                  False
#
#    category_travel  merchant_freq  job_freq  city_freq  state_freq  \
# 0            False           1267      3545       2028       30266
# 1            False           2503      5099       3545       18924
#
#    distance_km
# 0    78.597568
# 1    30.212176
#
# [2 rows x 26 columns]

# %%
new_unscaled_data2.shape
# Out:
# (1296675, 26)

# %%
from sklearn.model_selection import train_test_split

X = new_unscaled_data2.drop('is_fraud', axis=1)
Y = new_unscaled_data2['is_fraud']
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
print(Y_test.value_counts(normalize=True)*100)
print(Y_train.value_counts(normalize=True)*100)
# Out:
# is_fraud
# 0    99.413886
# 1     0.586114
# Name: proportion, dtype: float64
# is_fraud
# 0    99.422947
# 1     0.577053
# Name: proportion, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler
scalar = StandardScaler()
numeric_cols = ['amt', 'city_pop', 'age', 'distance_km', 'hours', 'month', 'day_of_week',
                 'merchant_freq', 'job_freq', 'city_freq', 'state_freq']


X_train[numeric_cols] = scalar.fit_transform(X_train[numeric_cols])


X_test[numeric_cols] = scalar.transform(X_test[numeric_cols])

# %%
from sklearn.ensemble import RandomForestClassifier
model= RandomForestClassifier(class_weight= 'balanced', random_state=42)
model.fit(X_train,Y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', random_state=42)

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

print("Accuracy:", accuracy_score(Y_test, y_pred))
print("Classification Report:")
print(classification_report(Y_test, y_pred))
print("Confusion Matrix:")
print(confusion_matrix(Y_test, y_pred))
# Out:
# Accuracy: 0.9987120905392639
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    257815
#            1       0.94      0.83      0.88      1520
#
#     accuracy                           1.00    259335
#    macro avg       0.97      0.92      0.94    259335
# weighted avg       1.00      1.00      1.00    259335
#
# Confusion Matrix:
# [[257737     78]
#  [   256   1264]]

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state=42)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train,Y_train)

model_smote = RandomForestClassifier(random_state=42)
model_smote.fit(X_train_resampled, y_train_resampled)

y_pred_smote = model_smote.predict(X_test)
print(classification_report(Y_test, y_pred_smote))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[99], line 7
#       3 smote = SMOTE(random_state=42)
#       4 X_train_resampled, y_train_resampled = smote.fit_resample(X_train,Y_train)
#       5
#       6 model_smote = RandomForestClassifier(random_state=42)
# ----> 7 model_smote.fit(X_train_resampled, y_train_resampled)
#       8
#       9 y_pred_smote = model_smote.predict(X_test)
#      10 print(classification_report(Y_test, y_pred_smote))
#
# File c:\Users\HP\AppData\Roaming\jupyter\runtime\.venv-tf\Lib\site-packages\sklearn\base.py:1403, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1393     estimator._validate_params()
#    1395 with (
#    1396     config_context(
#    1397         skip_parameter_validation=(
#    (...)   1401     callback_management_context(estimator),
#    1402 ):
# -> 1403     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\HP\AppData\Roaming\jupyter\runtime\.venv-tf\Lib\site-packages\sklearn\ensemble\_forest.py:468, in BaseForest.fit(self, X, y, sample_weight)
#     457 trees = [
#     458     self._make_estimator(append=False, random_state=random_state)
#     459     for i in range(n_more_estimators)
#     460 ]
#     462 # Parallel loop: we prefer the threading backend as the Cython code
#     463 # for fitting the trees is internally releasing the Python GIL
#     464 # making threading more efficient than multiprocessing in
#     465 # that case. However, for joblib 0.12+ we respect any
#     466 # parallel_backend contexts set at a higher level,
#     467 # since correctness does not rely on using threads.
# --> 468 trees = Parallel(
#     469     n_jobs=self.n_jobs,
#     470     verbose=self.verbose,
#     471     prefer="threads",
#     472 )(
#     473     delayed(_parallel_build_trees)(
#     474         t,
#     475         self.bootstrap,
#     476         X,
#     477         y,
#     478         _sample_weight,
#     479         i,
#     480         len(trees),
#     481         verbose=self.verbose,
#     482         class_weight=self.class_weight,
#     483         n_samples_bootstrap=n_samples_bootstrap,
#     484         missing_values_in_feature_mask=missing_values_in_feature_mask,
#     485     )
#     486     for i, t in enumerate(trees)
#     487 )
#     489 # Collect newly grown trees
#     490 self.estimators_.extend(trees)
#
# File c:\Users\HP\AppData\Roaming\jupyter\runtime\.venv-tf\Lib\site-packages\sklearn\utils\parallel.py:91, in Parallel.__call__(self, iterable)
#      79 warning_filters = (
#      80     filters_func() if filters_func is not None else warnings.filters
#      81 )
#      83 iterable_with_config_and_warning_filters = (
#      84     (
#      85         _with_config_and_warning_filters(delayed_func, config, warning_filters),
#    (...)     89     for delayed_func, args, kwargs in iterable
#      90 )
# ---> 91 return super().__call__(iterable_with_config_and_warning_filters)
#
# File c:\Users\HP\AppData\Roaming\jupyter\runtime\.venv-tf\Lib\site-packages\joblib\parallel.py:1986, in Parallel.__call__(self, iterable)
#    1984     output = self._get_sequential_output(iterable)
#    1985     next(output)
# -> 1986     return output if self.return_generator else list(output)
#    1988 # Let's create an ID that uniquely identifies the current call. If the
#    1989 # call is interrupted early and that the same instance is immediately
#    1990 # reused, this id will be used to prevent workers that were
#    1991 # concurrently finalizing a task from the previous call to run the
#    1992 # callback.
#    1993 with self._lock:
#
# File c:\Users\HP\AppData\Roaming\jupyter\runtime\.venv-tf\Lib\site-packages\joblib\parallel.py:1914, in Parallel._get_sequential_output(self, iterable)
#    1912 self.n_dispatched_batches += 1
#    1913 self.n_dispatched_tasks += 1
# -> 1914 res = func(*args, **kwargs)
#    1915 self.n_completed_tasks += 1
#    1916 self.print_progress()
#
# File c:\Users\HP\AppData\Roaming\jupyter\runtime\.venv-tf\Lib\site-packages\sklearn\utils\parallel.py:184, in _FuncWrapper.__call__(self, *args, **kwargs)
#     180                 this_warning_filter_dict[special_key] = this_value.pattern
#     182         warnings.filterwarnings(**this_warning_filter_dict, append=True)
# --> 184 return self.function(*args, **kwargs)
#
# File c:\Users\HP\AppData\Roaming\jupyter\runtime\.venv-tf\Lib\site-packages\sklearn\ensemble\_forest.py:163, in _parallel_build_trees(tree, bootstrap, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap, missing_values_in_feature_mask)
#     158         expanded_class_weight = compute_sample_weight(
#     159             "balanced", y, indices=indices
#     160         )
#     161         sample_weight_tree = sample_weight_tree * expanded_class_weight
# --> 163     tree._fit(
#     164         X,
#     165         y,
#     166         sample_weight=sample_weight_tree,
#     167         check_input=False,
#     168         missing_values_in_feature_mask=missing_values_in_feature_mask,
#     169     )
#     170 else:
#     171     tree._fit(
#     172         X,
#     173         y,
#    (...)    176         missing_values_in_feature_mask=missing_values_in_feature_mask,
#     177     )
#
# File c:\Users\HP\AppData\Roaming\jupyter\runtime\.venv-tf\Lib\site-packages\sklearn\tree\_classes.py:467, in BaseDecisionTree._fit(self, X, y, sample_weight, check_input, missing_values_in_feature_mask)
#     456 else:
#     457     builder = BestFirstTreeBuilder(
#     458         splitter,
#     459         min_samples_split,
#    (...)    464         self.min_impurity_decrease,
#     465     )
# --> 467 builder.build(self.tree_, X, y, sample_weight, missing_values_in_feature_mask)
#     469 if self.n_outputs_ == 1 and is_classifier(self):
#     470     self.n_classes_ = self.n_classes_[0]
#
# KeyboardInterrupt:
